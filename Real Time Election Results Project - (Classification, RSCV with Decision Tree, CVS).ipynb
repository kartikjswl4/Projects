# %% [markdown]
# # Real Time Election Results Project

# %% [markdown]
# Problem Statement:
# Real-time Election Results: Portugal 2019 Data Set
#
# A data set describing the evolution of results in the Portuguese Parliamentary Elections of October 6th 2019.
# The data spans a time interval of 4 hours and 25 minutes, in intervals of 5 minutes, concerning the results of the 27 parties involved in the electoral event.
#
# * Attribute Information:
#
# TimeElapsed (Numeric): Time (minutes) passed since the first data acquisition
#
# time (timestamp): Date and time of the data acquisition
#
# territoryName (string): Short name of the location (district or nation-wide)
#
# totalMandates (numeric): MP's elected at the moment
#
# availableMandates (numeric): MP's left to elect at the moment
#
# numParishes (numeric): Total number of parishes in this location
#
# numParishesApproved (numeric): Number of parishes approved in this location
#
# blankVotes (numeric): Number of blank votes
#
# blankVotesPercentage (numeric): Percentage of blank votes
#
# nullVotes (numeric): Number of null votes
#
# nullVotesPercentage (numeric): Percentage of null votes
#
# votersPercentage (numeric): Percentage of voters
#
# subscribedVoters (numeric): Number of subscribed voters in the location
#
# totalVoters (numeric): Percentage of blank votes
#
# pre.blankVotes (numeric): Number of blank votes (previous election)
#
# pre.blankVotesPercentage (numeric): Percentage of blank votes (previous election)
#
# pre.nullVotes (numeric): Number of null votes (previous election)
#
# pre.nullVotesPercentage (numeric): Percentage of null votes (previous election)
#
# pre.votersPercentage (numeric): Percentage of voters (previous election)
#
# pre.subscribedVoters (numeric): Number of subscribed voters in the location (previous election)
#
# pre.totalVoters (numeric): Percentage of blank votes (previous election)
#
# Party (string): Political Party
#
# Mandates (numeric): MP's elected at the moment for the party in a given district
#
# Percentage (numeric): Percentage of votes in a party
#
# validVotesPercentage (numeric): Percentage of valid votes in a party
#
# Votes (numeric): Percentage of party votes
#
# Hondt (numeric): Number of MP's according to the distribution of votes now
#
#
# * Target :
#
# FinalMandates (numeric): final number of elected MP's in a district/national-level
#
#
# Use the link below to download the dataset :
# https://github.com/dsrscientist/Dataset2/blob/main/election_data.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'Z:\ML Datasets\Election.csv')

# %%
df
# Out:
#       TimeElapsed              time       territoryName  totalMandates  \
# 0               0  06-10-2019 20:10  Territory National              0
# 1               0  06-10-2019 20:10  Territory National              0
# 2               0  06-10-2019 20:10  Territory National              0
# 3               0  06-10-2019 20:10  Territory National              0
# 4               0  06-10-2019 20:10  Territory National              0
# ...           ...               ...                 ...            ...
# 1208           15  06-10-2019 20:25                Beja              0
# 1209           15  06-10-2019 20:25                Beja              0
# 1210           15  06-10-2019 20:25                Beja              0
# 1211           15  06-10-2019 20:25                Beja              0
# 1212           15  06-10-2019 20:25                Beja              0
#
#       availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                   226         3092                 1081        9652
# 1                   226         3092                 1081        9652
# 2                   226         3092                 1081        9652
# 3                   226         3092                 1081        9652
# 4                   226         3092                 1081        9652
# ...                 ...          ...                  ...         ...
# 1208                  3           75                   23         125
# 1209                  3           75                   23         125
# 1210                  3           75                   23         125
# 1211                  3           75                   23         125
# 1212                  3           75                   23         125
#
#       blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                     2.50       8874  ...                 52.66
# 1                     2.50       8874  ...                 52.66
# 2                     2.50       8874  ...                 52.66
# 3                     2.50       8874  ...                 52.66
# 4                     2.50       8874  ...                 52.66
# ...                    ...        ...  ...                   ...
# 1208                  1.69        136  ...                 58.12
# 1209                  1.69        136  ...                 58.12
# 1210                  1.69        136  ...                 58.12
# 1211                  1.69        136  ...                 58.12
# 1212                  1.69        136  ...                 58.12
#
#       pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                   813743           428546       PS         0       38.29
# 1                   813743           428546  PPD/PSD         0       33.28
# 2                   813743           428546     B.E.         0        6.81
# 3                   813743           428546   CDS-PP         0        4.90
# 4                   813743           428546  PCP-PEV         0        4.59
# ...                    ...              ...      ...       ...         ...
# 1208                 15357             8926       IL         0        0.39
# 1209                 15357             8926        A         0        0.30
# 1210                 15357             8926      MPT         0        0.27
# 1211                 15357             8926      PDR         0        0.20
# 1212                 15357             8926      PNR         0        0.16
#
#       validVotesPercentage   Votes  Hondt  FinalMandates
# 0                    40.22  147993     94            106
# 1                    34.95  128624     81             77
# 2                     7.15   26307     16             19
# 3                     5.14   18923     12              5
# 4                     4.83   17757     11             12
# ...                    ...     ...    ...            ...
# 1208                  0.41      29      0              0
# 1209                  0.31      22      0              0
# 1210                  0.28      20      0              0
# 1211                  0.21      15      0              0
# 1212                  0.17      12      0              0
#
# [1213 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               1213 non-null   int64
#  1   time                      1213 non-null   object
#  2   territoryName             1213 non-null   object
#  3   totalMandates             1213 non-null   int64
#  4   availableMandates         1213 non-null   int64
#  5   numParishes               1213 non-null   int64
#  6   numParishesApproved       1213 non-null   int64
#  7   blankVotes                1213 non-null   int64
#  8   blankVotesPercentage      1213 non-null   float64
#  9   nullVotes                 1213 non-null   int64
#  10  nullVotesPercentage       1213 non-null   float64
#  11  votersPercentage          1213 non-null   float64
#  12  subscribedVoters          1213 non-null   int64
#  13  totalVoters               1213 non-null   int64
#  14  pre.blankVotes            1213 non-null   int64
#  15  pre.blankVotesPercentage  1213 non-null   float64
#  16  pre.nullVotes             1213 non-null   int64
#  17  pre.nullVotesPercentage   1213 non-null   float64
#  18  pre.votersPercentage      1213 non-null   float64
#  19  pre.subscribedVoters      1213 non-null   int64
#  20  pre.totalVoters           1213 non-null   int64
#  21  Party                     1213 non-null   object
#  22  Mandates                  1213 non-null   int64
#  23  Percentage                1213 non-null   float64
#  24  validVotesPercentage      1213 non-null   float64
#  25  Votes                     1213 non-null   int64
#  26  Hondt                     1213 non-null   int64
#  27  FinalMandates             1213 non-null   int64
# dtypes: float64(8), int64(17), object(3)
# memory usage: 265.5+ KB

# %%
df.nunique()
# Out:
# TimeElapsed                   4
# time                          4
# territoryName                20
# totalMandates                 1
# availableMandates            14
# numParishes                  19
# numParishesApproved          19
# blankVotes                   23
# blankVotesPercentage         21
# nullVotes                    23
# nullVotesPercentage          22
# votersPercentage             23
# subscribedVoters             23
# totalVoters                  23
# pre.blankVotes               23
# pre.blankVotesPercentage     21
# pre.nullVotes                22
# pre.nullVotesPercentage      21
# pre.votersPercentage         23
# pre.subscribedVoters         23
# pre.totalVoters              23
# Party                        21
# Mandates                      1
# Percentage                  219
# validVotesPercentage        233
# Votes                       274
# Hondt                        19
# FinalMandates                17
# dtype: int64

# %% [markdown]
# # EDA

# %%
sns.countplot(df['TimeElapsed'])
# Out:
# <AxesSubplot:xlabel='TimeElapsed', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
sns.countplot(df['time'])
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['territoryName'])
# Out:
# <AxesSubplot:xlabel='territoryName', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['availableMandates'])
# Out:
# <AxesSubplot:xlabel='availableMandates', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['numParishes'])
# Out:
# <AxesSubplot:xlabel='numParishes', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['numParishesApproved'])
# Out:
# <AxesSubplot:xlabel='numParishesApproved', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['blankVotes'])
# Out:
# <AxesSubplot:xlabel='blankVotes', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['blankVotesPercentage'])
# Out:
# <AxesSubplot:xlabel='blankVotesPercentage', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['votersPercentage'])
# Out:
# <AxesSubplot:xlabel='votersPercentage', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['subscribedVoters'])
# Out:
# <AxesSubplot:xlabel='subscribedVoters', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['totalVoters'])
# Out:
# <AxesSubplot:xlabel='totalVoters', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['pre.blankVotes'])
# Out:
# <AxesSubplot:xlabel='pre.blankVotes', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['pre.blankVotesPercentage'])
# Out:
# <AxesSubplot:xlabel='pre.blankVotesPercentage', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['pre.nullVotes'])
# Out:
# <AxesSubplot:xlabel='pre.nullVotes', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['pre.nullVotesPercentage'])
# Out:
# <AxesSubplot:xlabel='pre.nullVotesPercentage', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['pre.subscribedVoters'])
# Out:
# <AxesSubplot:xlabel='pre.subscribedVoters', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['pre.totalVoters'])
# Out:
# <AxesSubplot:xlabel='pre.totalVoters', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['Party'])
# Out:
# <AxesSubplot:xlabel='Party', ylabel='count'>

# %%
plt.figure(figsize=(25,7))
sns.countplot(df['Hondt'])
# Out:
# <AxesSubplot:xlabel='Hondt', ylabel='count'>

# %%
sns.scatterplot(data = df, x = 'Percentage', y = 'FinalMandates')
# Out:
# <AxesSubplot:xlabel='Percentage', ylabel='FinalMandates'>

# %%
sns.scatterplot(data = df, x = 'validVotesPercentage', y = 'FinalMandates')
# Out:
# <AxesSubplot:xlabel='validVotesPercentage', ylabel='FinalMandates'>

# %%
sns.scatterplot(data = df, x = 'Votes', y = 'FinalMandates')
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='FinalMandates'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df.apply(le.fit_transform)
df
# Out:
#       TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 0               0     0             16              0                 13
# 1               0     0             16              0                 13
# 2               0     0             16              0                 13
# 3               0     0             16              0                 13
# 4               0     0             16              0                 13
# ...           ...   ...            ...            ...                ...
# 1208            3     3              2              0                  1
# 1209            3     3              2              0                  1
# 1210            3     3              2              0                  1
# 1211            3     3              2              0                  1
# 1212            3     3              2              0                  1
#
#       numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 0              18                   18          22                    12
# 1              18                   18          22                    12
# 2              18                   18          22                    12
# 3              18                   18          22                    12
# 4              18                   18          22                    12
# ...           ...                  ...         ...                   ...
# 1208            4                    7           3                     3
# 1209            4                    7           3                     3
# 1210            4                    7           3                     3
# 1211            4                    7           3                     3
# 1212            4                    7           3                     3
#
#       nullVotes  ...  pre.votersPercentage  pre.subscribedVoters  \
# 0            22  ...                     9                    22
# 1            22  ...                     9                    22
# 2            22  ...                     9                    22
# 3            22  ...                     9                    22
# 4            22  ...                     9                    22
# ...         ...  ...                   ...                   ...
# 1208          6  ...                    18                     8
# 1209          6  ...                    18                     8
# 1210          6  ...                    18                     8
# 1211          6  ...                    18                     8
# 1212          6  ...                    18                     8
#
#       pre.totalVoters  Party  Mandates  Percentage  validVotesPercentage  \
# 0                  22     17         0         202                   215
# 1                  22     15         0         186                   199
# 2                  22      1         0         161                   169
# 3                  22      2         0         143                   151
# 4                  22     11         0         139                   147
# ...               ...    ...       ...         ...                   ...
# 1208                8      4         0          36                    38
# 1209                8      0         0          27                    28
# 1210                8      8         0          24                    25
# 1211                8     13         0          17                    18
# 1212                8     14         0          13                    14
#
#       Votes  Hondt  FinalMandates
# 0       273     18             16
# 1       272     16             15
# 2       269     13             13
# 3       265     11              5
# 4       264     10             10
# ...     ...    ...            ...
# 1208     27      0              0
# 1209     20      0              0
# 1210     18      0              0
# 1211     13      0              0
# 1212     10      0              0
#
# [1213 rows x 28 columns]

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                           TimeElapsed      time  territoryName  totalMandates  \
# TimeElapsed                  1.000000  1.000000      -0.047845            NaN
# time                         1.000000  1.000000      -0.047845            NaN
# territoryName               -0.047845 -0.047845       1.000000            NaN
# totalMandates                     NaN       NaN            NaN            NaN
# availableMandates            0.058275  0.058275       0.246961            NaN
# numParishes                  0.040312  0.040312       0.250418            NaN
# numParishesApproved          0.027571  0.027571       0.305131            NaN
# blankVotes                   0.007765  0.007765       0.363472            NaN
# blankVotesPercentage        -0.001680 -0.001680      -0.062769            NaN
# nullVotes                    0.007703  0.007703       0.377983            NaN
# nullVotesPercentage         -0.047589 -0.047589       0.060605            NaN
# votersPercentage             0.010310  0.010310      -0.353796            NaN
# subscribedVoters             0.026602  0.026602       0.378636            NaN
# totalVoters                  0.014226  0.014226       0.355658            NaN
# pre.blankVotes               0.013820  0.013820       0.376997            NaN
# pre.blankVotesPercentage    -0.024755 -0.024755       0.107308            NaN
# pre.nullVotes                0.033967  0.033967       0.400125            NaN
# pre.nullVotesPercentage     -0.050268 -0.050268       0.138542            NaN
# pre.votersPercentage         0.007670  0.007670      -0.350203            NaN
# pre.subscribedVoters         0.025108  0.025108       0.382722            NaN
# pre.totalVoters              0.024376  0.024376       0.366591            NaN
# Party                       -0.008017 -0.008017       0.000746            NaN
# Mandates                          NaN       NaN            NaN            NaN
# Percentage                   0.001220  0.001220      -0.001930            NaN
# validVotesPercentage         0.001141  0.001141      -0.004091            NaN
# Votes                        0.035497  0.035497       0.226051            NaN
# Hondt                        0.040181  0.040181       0.123230            NaN
# FinalMandates                0.035834  0.035834       0.105569            NaN
#
#                           availableMandates  numParishes  numParishesApproved  \
# TimeElapsed                        0.058275     0.040312             0.027571
# time                               0.058275     0.040312             0.027571
# territoryName                      0.246961     0.250418             0.305131
# totalMandates                           NaN          NaN                  NaN
# availableMandates                  1.000000     0.373803            -0.158914
# numParishes                        0.373803     1.000000             0.752526
# numParishesApproved               -0.158914     0.752526             1.000000
# blankVotes                         0.162314     0.786601             0.853720
# blankVotesPercentage               0.363329     0.332445             0.115887
# nullVotes                          0.086196     0.799388             0.896415
# nullVotesPercentage                0.119843     0.500212             0.462910
# votersPercentage                   0.209342    -0.173581            -0.402983
# subscribedVoters                   0.000424     0.790922             0.940040
# totalVoters                        0.028876     0.801803             0.924943
# pre.blankVotes                     0.100464     0.785291             0.893836
# pre.blankVotesPercentage           0.236615     0.296426             0.230774
# pre.nullVotes                      0.022863     0.756760             0.922151
# pre.nullVotesPercentage           -0.039270     0.069658             0.179598
# pre.votersPercentage               0.054436    -0.433579            -0.493266
# pre.subscribedVoters              -0.019415     0.776508             0.946450
# pre.totalVoters                   -0.022017     0.799576             0.953365
# Party                             -0.002271    -0.003451             0.001045
# Mandates                                NaN          NaN                  NaN
# Percentage                        -0.029558    -0.057837            -0.030954
# validVotesPercentage              -0.029257    -0.056972            -0.030546
# Votes                              0.093710     0.350073             0.431243
# Hondt                              0.305627     0.175820             0.075788
# FinalMandates                      0.302369     0.159624             0.044063
#
#                           blankVotes  blankVotesPercentage  nullVotes  ...  \
# TimeElapsed                 0.007765             -0.001680   0.007703  ...
# time                        0.007765             -0.001680   0.007703  ...
# territoryName               0.363472             -0.062769   0.377983  ...
# totalMandates                    NaN                   NaN        NaN  ...
# availableMandates           0.162314              0.363329   0.086196  ...
# numParishes                 0.786601              0.332445   0.799388  ...
# numParishesApproved         0.853720              0.115887   0.896415  ...
# blankVotes                  1.000000              0.499218   0.930477  ...
# blankVotesPercentage        0.499218              1.000000   0.301741  ...
# nullVotes                   0.930477              0.301741   1.000000  ...
# nullVotesPercentage         0.561260              0.388502   0.705717  ...
# votersPercentage           -0.142115              0.252847  -0.187770  ...
# subscribedVoters            0.909378              0.184498   0.935906  ...
# totalVoters                 0.942056              0.245967   0.953378  ...
# pre.blankVotes              0.985212              0.452237   0.957972  ...
# pre.blankVotesPercentage    0.532818              0.881751   0.410087  ...
# pre.nullVotes               0.927837              0.260499   0.950970  ...
# pre.nullVotesPercentage     0.195124              0.210750   0.266277  ...
# pre.votersPercentage       -0.315178              0.065994  -0.356356  ...
# pre.subscribedVoters        0.910282              0.193276   0.932463  ...
# pre.totalVoters             0.917079              0.181144   0.936646  ...
# Party                       0.005647              0.002708  -0.000864  ...
# Mandates                         NaN                   NaN        NaN  ...
# Percentage                 -0.035323             -0.015647  -0.033072  ...
# validVotesPercentage       -0.033747             -0.012082  -0.031499  ...
# Votes                       0.428217              0.082049   0.432437  ...
# Hondt                       0.107882              0.038515   0.108430  ...
# FinalMandates               0.085265              0.046977   0.083040  ...
#
#                           pre.votersPercentage  pre.subscribedVoters  \
# TimeElapsed                           0.007670              0.025108
# time                                  0.007670              0.025108
# territoryName                        -0.350203              0.382722
# totalMandates                              NaN                   NaN
# availableMandates                     0.054436             -0.019415
# numParishes                          -0.433579              0.776508
# numParishesApproved                  -0.493266              0.946450
# blankVotes                           -0.315178              0.910282
# blankVotesPercentage                  0.065994              0.193276
# nullVotes                            -0.356356              0.932463
# nullVotesPercentage                  -0.148839              0.480285
# votersPercentage                      0.874593             -0.317670
# subscribedVoters                     -0.414025              0.998073
# totalVoters                          -0.352443              0.982349
# pre.blankVotes                       -0.351001              0.922522
# pre.blankVotesPercentage              0.069587              0.266500
# pre.nullVotes                        -0.444119              0.954827
# pre.nullVotesPercentage              -0.332302              0.156946
# pre.votersPercentage                  1.000000             -0.426091
# pre.subscribedVoters                 -0.426091              1.000000
# pre.totalVoters                      -0.373058              0.988082
# Party                                 0.000779             -0.002556
# Mandates                                   NaN                   NaN
# Percentage                            0.054619             -0.032683
# validVotesPercentage                  0.057123             -0.032080
# Votes                                -0.136384              0.442758
# Hondt                                -0.014047              0.092856
# FinalMandates                        -0.001710              0.063949
#
#                           pre.totalVoters     Party  Mandates  Percentage  \
# TimeElapsed                      0.024376 -0.008017       NaN    0.001220
# time                             0.024376 -0.008017       NaN    0.001220
# territoryName                    0.366591  0.000746       NaN   -0.001930
# totalMandates                         NaN       NaN       NaN         NaN
# availableMandates               -0.022017 -0.002271       NaN   -0.029558
# numParishes                      0.799576 -0.003451       NaN   -0.057837
# numParishesApproved              0.953365  0.001045       NaN   -0.030954
# blankVotes                       0.917079  0.005647       NaN   -0.035323
# blankVotesPercentage             0.181144  0.002708       NaN   -0.015647
# nullVotes                        0.936646 -0.000864       NaN   -0.033072
# nullVotesPercentage              0.478161 -0.001041       NaN   -0.012905
# votersPercentage                -0.254541  0.000498       NaN    0.025447
# subscribedVoters                 0.990287 -0.002016       NaN   -0.033986
# totalVoters                      0.986041  0.000155       NaN   -0.036285
# pre.blankVotes                   0.932789  0.002959       NaN   -0.031699
# pre.blankVotesPercentage         0.258278  0.006160       NaN   -0.000118
# pre.nullVotes                    0.946710  0.002954       NaN   -0.031243
# pre.nullVotesPercentage          0.090054  0.010950       NaN   -0.005029
# pre.votersPercentage            -0.373058  0.000779       NaN    0.054619
# pre.subscribedVoters             0.988082 -0.002556       NaN   -0.032683
# pre.totalVoters                  1.000000 -0.000672       NaN   -0.031630
# Party                           -0.000672  1.000000       NaN   -0.057436
# Mandates                              NaN       NaN       NaN         NaN
# Percentage                      -0.031630 -0.057436       NaN    1.000000
# validVotesPercentage            -0.030890 -0.055532       NaN    0.999824
# Votes                            0.445300 -0.034102       NaN    0.837653
# Hondt                            0.093465  0.141085       NaN    0.530110
# FinalMandates                    0.065548  0.140973       NaN    0.559260
#
#                           validVotesPercentage     Votes     Hondt  \
# TimeElapsed                           0.001141  0.035497  0.040181
# time                                  0.001141  0.035497  0.040181
# territoryName                        -0.004091  0.226051  0.123230
# totalMandates                              NaN       NaN       NaN
# availableMandates                    -0.029257  0.093710  0.305627
# numParishes                          -0.056972  0.350073  0.175820
# numParishesApproved                  -0.030546  0.431243  0.075788
# blankVotes                           -0.033747  0.428217  0.107882
# blankVotesPercentage                 -0.012082  0.082049  0.038515
# nullVotes                            -0.031499  0.432437  0.108430
# nullVotesPercentage                  -0.009374  0.209759  0.058870
# votersPercentage                      0.027971 -0.093780  0.011066
# subscribedVoters                     -0.033422  0.441619  0.096310
# totalVoters                          -0.035289  0.438781  0.094809
# pre.blankVotes                       -0.030058  0.434873  0.101536
# pre.blankVotesPercentage              0.003799  0.127331  0.039428
# pre.nullVotes                        -0.030554  0.443623  0.099447
# pre.nullVotesPercentage              -0.004521  0.064425  0.007095
# pre.votersPercentage                  0.057123 -0.136384 -0.014047
# pre.subscribedVoters                 -0.032080  0.442758  0.092856
# pre.totalVoters                      -0.030890  0.445300  0.093465
# Party                                -0.055532 -0.034102  0.141085
# Mandates                                   NaN       NaN       NaN
# Percentage                            0.999824  0.837653  0.530110
# validVotesPercentage                  1.000000  0.837456  0.529550
# Votes                                 0.837456  1.000000  0.536261
# Hondt                                 0.529550  0.536261  1.000000
# FinalMandates                         0.558700  0.541329  0.977095
#
#                           FinalMandates
# TimeElapsed                    0.035834
# time                           0.035834
# territoryName                  0.105569
# totalMandates                       NaN
# availableMandates              0.302369
# numParishes                    0.159624
# numParishesApproved            0.044063
# blankVotes                     0.085265
# blankVotesPercentage           0.046977
# nullVotes                      0.083040
# nullVotesPercentage            0.053343
# votersPercentage               0.025891
# subscribedVoters               0.068165
# totalVoters                    0.068228
# pre.blankVotes                 0.077285
# pre.blankVotesPercentage       0.042271
# pre.nullVotes                  0.071206
# pre.nullVotesPercentage        0.000016
# pre.votersPercentage          -0.001710
# pre.subscribedVoters           0.063949
# pre.totalVoters                0.065548
# Party                          0.140973
# Mandates                            NaN
# Percentage                     0.559260
# validVotesPercentage           0.558700
# Votes                          0.541329
# Hondt                          0.977095
# FinalMandates                  1.000000
#
# [28 rows x 28 columns]

# %%
plt.figure(figsize=(25,18))
sns.heatmap(df.corr(), annot = True, linewidth = 0.5, linecolor = 'Black', cmap = 'RdYlGn')
# Out:
# <AxesSubplot:>

# %%
df.corr().sum()
# Out:
# TimeElapsed                  2.231423
# time                         2.231423
# territoryName                4.698264
# totalMandates                0.000000
# availableMandates            3.523019
# numParishes                  9.913056
# numParishesApproved          9.868362
# blankVotes                  11.593024
# blankVotesPercentage         6.006476
# nullVotes                   11.471369
# nullVotesPercentage          8.030065
# votersPercentage            -0.568518
# subscribedVoters            10.737673
# totalVoters                 11.086580
# pre.blankVotes              11.640222
# pre.blankVotesPercentage     6.967215
# pre.nullVotes               11.138587
# pre.nullVotesPercentage      3.408477
# pre.votersPercentage        -2.750127
# pre.subscribedVoters        10.710570
# pre.totalVoters             10.765061
# Party                        1.140682
# Mandates                     0.000000
# Percentage                   3.532018
# validVotesPercentage         3.556792
# Votes                        8.651674
# Hondt                        5.410592
# FinalMandates                5.210122
# dtype: float64

# %%
x = df.drop(['FinalMandates'], axis = 1)

def correlation(dataset, threshold):
    corr_columns = set()
    corr = dataset.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i,j]) > threshold:
                columns = corr.columns[i]
                corr_columns.add(columns)
    return corr_columns

# %%
corr_feat = correlation(x, 0.85)
corr_feat
# Out:
# {'blankVotes',
#  'nullVotes',
#  'pre.blankVotes',
#  'pre.blankVotesPercentage',
#  'pre.nullVotes',
#  'pre.subscribedVoters',
#  'pre.totalVoters',
#  'pre.votersPercentage',
#  'subscribedVoters',
#  'time',
#  'totalVoters',
#  'validVotesPercentage'}

# %%
df = df.drop(corr_feat, axis =1)
df
# Out:
#       TimeElapsed  territoryName  totalMandates  availableMandates  \
# 0               0             16              0                 13
# 1               0             16              0                 13
# 2               0             16              0                 13
# 3               0             16              0                 13
# 4               0             16              0                 13
# ...           ...            ...            ...                ...
# 1208            3              2              0                  1
# 1209            3              2              0                  1
# 1210            3              2              0                  1
# 1211            3              2              0                  1
# 1212            3              2              0                  1
#
#       numParishes  numParishesApproved  blankVotesPercentage  \
# 0              18                   18                    12
# 1              18                   18                    12
# 2              18                   18                    12
# 3              18                   18                    12
# 4              18                   18                    12
# ...           ...                  ...                   ...
# 1208            4                    7                     3
# 1209            4                    7                     3
# 1210            4                    7                     3
# 1211            4                    7                     3
# 1212            4                    7                     3
#
#       nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  Party  \
# 0                      12                11                        9     17
# 1                      12                11                        9     15
# 2                      12                11                        9      1
# 3                      12                11                        9      2
# 4                      12                11                        9     11
# ...                   ...               ...                      ...    ...
# 1208                    5                13                        3      4
# 1209                    5                13                        3      0
# 1210                    5                13                        3      8
# 1211                    5                13                        3     13
# 1212                    5                13                        3     14
#
#       Mandates  Percentage  Votes  Hondt  FinalMandates
# 0            0         202    273     18             16
# 1            0         186    272     16             15
# 2            0         161    269     13             13
# 3            0         143    265     11              5
# 4            0         139    264     10             10
# ...        ...         ...    ...    ...            ...
# 1208         0          36     27      0              0
# 1209         0          27     20      0              0
# 1210         0          24     18      0              0
# 1211         0          17     13      0              0
# 1212         0          13     10      0              0
#
# [1213 rows x 16 columns]

# %%
df.plot(kind = 'box', subplots = True, layout = (3,6), figsize=(18,10))
# Out:
# TimeElapsed                   AxesSubplot(0.125,0.657941;0.110714x0.222059)
# territoryName              AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# totalMandates              AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# availableMandates          AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# numParishes                AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# numParishesApproved        AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# blankVotesPercentage          AxesSubplot(0.125,0.391471;0.110714x0.222059)
# nullVotesPercentage        AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# votersPercentage           AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# pre.nullVotesPercentage    AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# Party                      AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# Mandates                   AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# Percentage                       AxesSubplot(0.125,0.125;0.110714x0.222059)
# Votes                         AxesSubplot(0.257857,0.125;0.110714x0.222059)
# Hondt                         AxesSubplot(0.390714,0.125;0.110714x0.222059)
# FinalMandates                 AxesSubplot(0.523571,0.125;0.110714x0.222059)
# dtype: object

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
df.shape
# Out:
# (1213, 16)

# %%
z = pd.DataFrame(zscore(df))
z.fillna(0, inplace=True)
df1 = df[(z<3).all(axis=1)]

df.shape, df1.shape
# Out:
# ((1213, 16), (1172, 16))

# %%
loss = (((1213 - 1172)/1213)*100)
loss
# Out:
# 3.3800494641384993

# %% [markdown]
# # Skewness

# %%
df1.skew()
# Out:
# TimeElapsed                0.189030
# territoryName              0.016606
# totalMandates              0.000000
# availableMandates          0.310139
# numParishes                0.103585
# numParishesApproved        0.189851
# blankVotesPercentage      -0.205497
# nullVotesPercentage        0.066634
# votersPercentage          -0.159826
# pre.nullVotesPercentage    0.069220
# Party                     -0.044907
# Mandates                   0.000000
# Percentage                 0.932733
# Votes                      0.697333
# Hondt                      3.380704
# FinalMandates              3.364154
# dtype: float64

# %%
fig, ax = plt.subplots(nrows = 3, ncols = 6, figsize=(18,10))
index = 0
ax = ax.flatten()

for col, value in df1.items():
     if col!= 'type':
        sns.histplot(data = df1, x = col, ax = ax[index], kde = True)
        index += 1
plt.tight_layout()

# %%
df1.describe()
# Out:
#        TimeElapsed  territoryName  totalMandates  availableMandates  \
# count  1172.000000    1172.000000         1172.0        1172.000000
# mean      1.085324       9.283276            0.0           5.614334
# std       0.895700       5.867593            0.0           3.880768
# min       0.000000       0.000000            0.0           0.000000
# 25%       0.000000       4.000000            0.0           2.000000
# 50%       1.000000       9.000000            0.0           6.000000
# 75%       2.000000      14.000000            0.0           8.000000
# max       3.000000      19.000000            0.0          13.000000
#
#        numParishes  numParishesApproved  blankVotesPercentage  \
# count  1172.000000          1172.000000           1172.000000
# mean      8.730375             8.382253             11.010239
# std       5.498296             5.014305              5.959433
# min       0.000000             0.000000              0.000000
# 25%       4.000000             4.000000              6.000000
# 50%       9.000000             7.000000             11.000000
# 75%      14.000000            14.000000             16.000000
# max      18.000000            18.000000             20.000000
#
#        nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# count          1172.000000       1172.000000              1172.000000
# mean             10.193686         11.795222                 9.031570
# std               6.299732          6.485802                 6.122004
# min               0.000000          0.000000                 0.000000
# 25%               5.000000          6.000000                 4.000000
# 50%              10.000000         13.000000                 9.000000
# 75%              15.000000         17.000000                14.000000
# max              21.000000         22.000000                20.000000
#
#              Party  Mandates   Percentage        Votes        Hondt  \
# count  1172.000000    1172.0  1172.000000  1172.000000  1172.000000
# mean     10.013652       0.0    68.119454    89.937713     0.362628
# std       6.130364       0.0    60.324933    76.002126     1.044232
# min       0.000000       0.0     0.000000     0.000000     0.000000
# 25%       4.000000       0.0    18.000000    23.000000     0.000000
# 50%      10.000000       0.0    45.000000    68.000000     0.000000
# 75%      15.000000       0.0   107.000000   148.000000     0.000000
# max      20.000000       0.0   218.000000   268.000000     6.000000
#
#        FinalMandates
# count    1172.000000
# mean        0.377986
# std         1.070349
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         7.000000

# %%
X = df1.drop(['FinalMandates'], axis = 1)
Y = df1['FinalMandates']

# %%
from sklearn.preprocessing import power_transform
X = power_transform(X, method = 'yeo-johnson')
X
# Out:
# array([[-1.28935086,  1.09728288,  0.        , ...,  0.83727318,
#          1.56319825,  2.40905931],
#        [-1.28935086,  1.09728288,  0.        , ...,  0.52480157,
#          1.50596198,  2.40380022],
#        [-1.28935086,  1.09728288,  0.        , ...,  0.48329109,
#          1.48259221,  2.40380022],
#        ...,
#        [ 1.82192136, -1.26911702,  0.        , ..., -0.61274476,
#         -1.00029215, -0.41893784],
#        [ 1.82192136, -1.26911702,  0.        , ..., -0.9035164 ,
#         -1.19616577, -0.41893784],
#        [ 1.82192136, -1.26911702,  0.        , ..., -1.1166079 ,
#         -1.33909371, -0.41893784]])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-1.28935086,  1.09728288,  0.        , ...,  0.83727318,
#          1.56319825,  2.40905931],
#        [-1.28935086,  1.09728288,  0.        , ...,  0.52480157,
#          1.50596198,  2.40380022],
#        [-1.28935086,  1.09728288,  0.        , ...,  0.48329109,
#          1.48259221,  2.40380022],
#        ...,
#        [ 1.82192136, -1.26911702,  0.        , ..., -0.61274476,
#         -1.00029215, -0.41893784],
#        [ 1.82192136, -1.26911702,  0.        , ..., -0.9035164 ,
#         -1.19616577, -0.41893784],
#        [ 1.82192136, -1.26911702,  0.        , ..., -1.1166079 ,
#         -1.33909371, -0.41893784]])

# %%
X = pd.DataFrame(X)

# %%
Y.value_counts()
# Out:
# 0    991
# 1     68
# 2     38
# 3     33
# 4     22
# 5     12
# 6      4
# 7      4
# Name: FinalMandates, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()
X, Y = ros.fit_resample(X,Y)
Y.value_counts()
# Out:
# 4    991
# 1    991
# 0    991
# 6    991
# 7    991
# 2    991
# 3    991
# 5    991
# Name: FinalMandates, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 10)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, Y_train)
pred = lr.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(lr, X, Y, cv = None)
cvs.mean()
# Out:
# [[207   8   0   0   1   0   0   0]
#  [  0 148  48   0   0   0   0   0]
#  [  0  14 159   3   0   0   0   0]
#  [  0   0  17 173  21   0   0   0]
#  [  0   0   0   0 176   0   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0 203   0]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       216
#            1       0.87      0.76      0.81       196
#            2       0.71      0.90      0.80       176
#            3       0.98      0.82      0.89       211
#            4       0.89      1.00      0.94       176
#            5       1.00      1.00      1.00       212
#            6       1.00      1.00      1.00       203
#            7       1.00      1.00      1.00       196
#
#     accuracy                           0.93      1586
#    macro avg       0.93      0.93      0.93      1586
# weighted avg       0.94      0.93      0.93      1586
#
# 0.9293820933165196
# 0.934407930591413

# %%
#RandomForest

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
pred = rf.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(rf,  X, Y,  cv=None)
cvs.mean()
# Out:
# [[216   0   0   0   0   0   0   0]
#  [  0 196   0   0   0   0   0   0]
#  [  0   0 176   0   0   0   0   0]
#  [  0   0   0 211   0   0   0   0]
#  [  0   0   0   0 176   0   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0 203   0]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       216
#            1       1.00      1.00      1.00       196
#            2       1.00      1.00      1.00       176
#            3       1.00      1.00      1.00       211
#            4       1.00      1.00      1.00       176
#            5       1.00      1.00      1.00       212
#            6       1.00      1.00      1.00       203
#            7       1.00      1.00      1.00       196
#
#     accuracy                           1.00      1586
#    macro avg       1.00      1.00      1.00      1586
# weighted avg       1.00      1.00      1.00      1586
#
# 1.0
# 0.9997477931904161

# %%
#DescisonTree

from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
pred = dt.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(dt, X, Y,  cv=None)
cvs.mean()
# Out:
# [[216   0   0   0   0   0   0   0]
#  [  0 196   0   0   0   0   0   0]
#  [  0   0 176   0   0   0   0   0]
#  [  0   0   0 211   0   0   0   0]
#  [  0   0   0   0 176   0   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0 203   0]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       216
#            1       1.00      1.00      1.00       196
#            2       1.00      1.00      1.00       176
#            3       1.00      1.00      1.00       211
#            4       1.00      1.00      1.00       176
#            5       1.00      1.00      1.00       212
#            6       1.00      1.00      1.00       203
#            7       1.00      1.00      1.00       196
#
#     accuracy                           1.00      1586
#    macro avg       1.00      1.00      1.00      1586
# weighted avg       1.00      1.00      1.00      1586
#
# 1.0
# 0.9998738965952081

# %%
#SVC

from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, Y_train)
pred = svc.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(svc, X, Y,  cv=None)
cvs.mean()
# Out:
# [[209   5   1   0   1   0   0   0]
#  [  0 143  42   5   6   0   0   0]
#  [  0   0 151  10   0  15   0   0]
#  [  0   0   0 190  21   0   0   0]
#  [  0   0   0   0 176   0   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0 203   0]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       216
#            1       0.97      0.73      0.83       196
#            2       0.78      0.86      0.82       176
#            3       0.93      0.90      0.91       211
#            4       0.86      1.00      0.93       176
#            5       0.93      1.00      0.97       212
#            6       1.00      1.00      1.00       203
#            7       1.00      1.00      1.00       196
#
#     accuracy                           0.93      1586
#    macro avg       0.93      0.93      0.93      1586
# weighted avg       0.94      0.93      0.93      1586
#
# 0.9331651954602774
# 0.9316327009598975

# %%
# KNN

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
pred = knn.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(knn, X, Y, cv=None)
cvs.mean()
# Out:
# [[209   5   1   0   1   0   0   0]
#  [  0 196   0   0   0   0   0   0]
#  [  0   0 176   0   0   0   0   0]
#  [  0   0   0 211   0   0   0   0]
#  [  0   0   0   0 176   0   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0 203   0]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       216
#            1       0.98      1.00      0.99       196
#            2       0.99      1.00      1.00       176
#            3       1.00      1.00      1.00       211
#            4       0.99      1.00      1.00       176
#            5       1.00      1.00      1.00       212
#            6       1.00      1.00      1.00       203
#            7       1.00      1.00      1.00       196
#
#     accuracy                           1.00      1586
#    macro avg       1.00      1.00      1.00      1586
# weighted avg       1.00      1.00      1.00      1586
#
# 0.9955863808322825
# 0.9931891431731117

# %%
#Naive Bayes

from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, Y_train)
pred = nb.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(nb,  X, Y,  cv=None)
cvs.mean()
# Out:
# [[192  23   1   0   0   0   0   0]
#  [ 30  62  95   0   9   0   0   0]
#  [  0   0 161   0  15   0   0   0]
#  [  0   0   0 190  21   0   0   0]
#  [  0   0  31  16 129   0   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0 203   0]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88       216
#            1       0.73      0.32      0.44       196
#            2       0.56      0.91      0.69       176
#            3       0.92      0.90      0.91       211
#            4       0.74      0.73      0.74       176
#            5       1.00      1.00      1.00       212
#            6       1.00      1.00      1.00       203
#            7       1.00      1.00      1.00       196
#
#     accuracy                           0.85      1586
#    macro avg       0.85      0.84      0.83      1586
# weighted avg       0.86      0.85      0.84      1586
#
# 0.8480453972257251
# 0.8367769242703307

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
criterion = ['gini', 'entropy', 'log_loss']
splitter = ['best', 'random']
max_depth = range(1, 9900, 300)
min_samples_split = range(1, 9900, 300)
min_samples_leaf = range(1, 9900, 300)
max_features = ['auto', 'sqrt', 'log2']

random_grid = {'criterion' : criterion,
               'splitter' : splitter,
               'max_depth' : max_depth,
               'min_samples_split' : min_samples_split,
               'min_samples_leaf' : min_samples_leaf,
               'max_features' : max_features}

random_grid
# Out:
# {'criterion': ['gini', 'entropy', 'log_loss'],
#  'splitter': ['best', 'random'],
#  'max_depth': range(1, 9900, 300),
#  'min_samples_split': range(1, 9900, 300),
#  'min_samples_leaf': range(1, 9900, 300),
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
dt = DecisionTreeClassifier()
rscv = RandomizedSearchCV(estimator = dt,
                         param_distributions = random_grid,
                         cv = 10,
                         random_state = 25,
                         verbose = 2,
                         n_jobs = -1)

rscv.fit(X_train, Y_train)
rscv
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomizedSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(1, 9900, 300),
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': range(1, 9900, 300),
#                                         'min_samples_split': range(1, 9900, 300),
#                                         'splitter': ['best', 'random']},
#                    random_state=25, verbose=2)

# %%
rscv.best_params_
# Out:
# {'splitter': 'best',
#  'min_samples_split': 2701,
#  'min_samples_leaf': 301,
#  'max_features': 'auto',
#  'max_depth': 301,
#  'criterion': 'gini'}

# %%
rscv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=301, max_features='auto', min_samples_leaf=301,
#                        min_samples_split=2701)

# %%
best_rscv = rscv.best_estimator_
pred = best_rscv.predict(X_test)

# %%
print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(rscv,  X, Y)
cvs.mean()
# Out:
# [[  0   0   0  94  43  46   0  33]
#  [  0   0   0  34  69  67   0  26]
#  [  0   0   0  79  13  42   0  42]
#  [  0   0   0 128  21  30   0  32]
#  [  0   0   0   0  99  77   0   0]
#  [  0   0   0   0   0 212   0   0]
#  [  0   0   0   0   0   0   0 203]
#  [  0   0   0   0   0   0   0 196]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       216
#            1       0.00      0.00      0.00       196
#            2       0.00      0.00      0.00       176
#            3       0.38      0.61      0.47       211
#            4       0.40      0.56      0.47       176
#            5       0.45      1.00      0.62       212
#            6       0.00      0.00      0.00       203
#            7       0.37      1.00      0.54       196
#
#     accuracy                           0.40      1586
#    macro avg       0.20      0.40      0.26      1586
# weighted avg       0.20      0.40      0.26      1586
#
# 0.4003783102143758
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# 0.4008496266623173

# %%
import pickle
filename = 'Election Results.pkl'
pickle.dump(rf, open(filename, 'wb'))
