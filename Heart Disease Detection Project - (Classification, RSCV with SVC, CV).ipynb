# %% [markdown]
# # Heart Disease Detection Project

# %% [markdown]
# Problem Statement:
#
# This database contains 14 attributes . In particular, the Cleveland database is the only one that has been used by ML researchers to this date.
# The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland database have concentrated on simply attempting to distinguish presence (values 1,2,3,4) from absence (value 0).
#
#
#
# Only 14 attributes used:
# 1. (age)
# 2. sex     // (1 = male; 0 = female)
# 3. cp      // chest pain type
# 4. trestbps// resting blood pressure (in mm Hg on admission to the hospital)
# 5. chol    // serum cholestoral in mg/dl
# 6. fbs     // (fasting blood sugar &gt; 120 mg/dl) (1 = true; 0 = false)
# 7. restecg // resting electrocardiographic results
# 8. thalach // maximum heart rate achieved
# 9. exang   // exercise induced angina (1 = yes; 0 = no)
# 10. oldpeak// ST depression induced by exercise relative to rest
# 11. slope  // the slope of the peak exercise ST segment
# 12. ca     // number of major vessels (0-3) colored by flourosopy
# 13. thal   //  0 = normal; 1 = fixed defect; 2 = reversable defect
# 14. target
#
#
#
# Use the link below to download the dataset.
#
# Downlaod Files:
# https://github.com/dsrscientist/dataset1/blob/master/heart_disease.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'Z:\ML Datasets\Heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# # EDA

# %%
sns.scatterplot(data = df, x = 'age', y = 'target', hue = 'age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='target'>

# %%
sns.countplot(data = df, x = 'sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(data = df, x ='cp')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.scatterplot(data = df, x = 'trestbps', y = 'target', hue = 'target')
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='target'>

# %%
sns.scatterplot(data =df, x = 'chol', y = 'target', hue = 'chol')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='target'>

# %%
sns.countplot(data = df, x ='fbs')
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='count'>

# %%
sns.countplot(data = df, x ='restecg')
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='count'>

# %%
sns.countplot(data = df, x ='exang')
# Out:
# <AxesSubplot:xlabel='exang', ylabel='count'>

# %%
sns.countplot(data = df, x ='slope')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %%
sns.countplot(data = df, x ='ca')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
sns.countplot(data = df, x ='thal')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %%
sns.scatterplot(data = df, x = 'thalach', y = 'target', hue = 'thalach')
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='target'>

# %%
sns.scatterplot(data = df, x = 'oldpeak', y = 'target', hue = 'thalach')
# Out:
# <AxesSubplot:xlabel='oldpeak', ylabel='target'>

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot = True, linecolor = 'black', linewidth = 0.5, cmap = 'RdYlGn')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box', subplots=True, layout=(11,7),figsize=(20,50))
# Out:
# age           AxesSubplot(0.125,0.821923;0.0945122x0.0580769)
# sex         AxesSubplot(0.238415,0.821923;0.0945122x0.0580...
# cp          AxesSubplot(0.351829,0.821923;0.0945122x0.0580...
# trestbps    AxesSubplot(0.465244,0.821923;0.0945122x0.0580...
# chol        AxesSubplot(0.578659,0.821923;0.0945122x0.0580...
# fbs         AxesSubplot(0.692073,0.821923;0.0945122x0.0580...
# restecg     AxesSubplot(0.805488,0.821923;0.0945122x0.0580...
# thalach       AxesSubplot(0.125,0.752231;0.0945122x0.0580769)
# exang       AxesSubplot(0.238415,0.752231;0.0945122x0.0580...
# oldpeak     AxesSubplot(0.351829,0.752231;0.0945122x0.0580...
# slope       AxesSubplot(0.465244,0.752231;0.0945122x0.0580...
# ca          AxesSubplot(0.578659,0.752231;0.0945122x0.0580...
# thal        AxesSubplot(0.692073,0.752231;0.0945122x0.0580...
# target      AxesSubplot(0.805488,0.752231;0.0945122x0.0580...
# dtype: object

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
z.shape
# Out:
# (303, 14)

# %%
print(np.where(z<3))
# Out:
# (array([  0,   0,   0, ..., 302, 302, 302], dtype=int64), array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))

# %%
df1 = df[(z<3).all(axis=1)]
print(df.shape)
print(df1.shape)
# Out:
# (303, 14)
# (287, 14)

# %%
#percentage of data loss

loss = ((303-287)/303)*100
loss
# Out:
# 5.2805280528052805

# %% [markdown]
# # Skewness

# %%
df1.skew()
# Out:
# age        -0.184321
# sex        -0.825426
# cp          0.491220
# trestbps    0.530712
# chol        0.245591
# fbs         2.051982
# restecg     0.155787
# thalach    -0.473864
# exang       0.738876
# oldpeak     0.984256
# slope      -0.503916
# ca          1.211037
# thal       -0.190864
# target     -0.204199
# dtype: float64

# %%
plt.figure(figsize=(18,7))
for i, column in enumerate(df.columns, 1):
    plt.subplot(4,4,i)
    sns.distplot(df[column])

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
X = df1.drop(['target'], axis = 1)
Y = df1['target']

# %%
#Transforming data to remove skewness
from sklearn.preprocessing import power_transform
X = power_transform(X, method='yeo-johnson')
X
# Out:
# array([[ 0.95799131,  0.67044385,  1.48238226, ..., -1.98923053,
#         -0.81818185, -2.126493  ],
#        [-1.83416693,  0.67044385,  1.05328631, ..., -1.98923053,
#         -0.81818185, -0.56420201],
#        [-1.44104734, -1.49154923,  0.37485853, ...,  1.00895664,
#         -0.81818185, -0.56420201],
#        ...,
#        [ 1.55264689,  0.67044385, -1.01780883, ..., -0.76249589,
#          1.39898882,  1.19549442],
#        [ 0.26717004,  0.67044385, -1.01780883, ..., -0.76249589,
#          0.95550207,  1.19549442],
#        [ 0.26717004, -1.49154923,  0.37485853, ..., -0.76249589,
#          0.95550207, -0.56420201]])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[ 0.95799131,  0.67044385,  1.48238226, ..., -1.98923053,
#         -0.81818185, -2.126493  ],
#        [-1.83416693,  0.67044385,  1.05328631, ..., -1.98923053,
#         -0.81818185, -0.56420201],
#        [-1.44104734, -1.49154923,  0.37485853, ...,  1.00895664,
#         -0.81818185, -0.56420201],
#        ...,
#        [ 1.55264689,  0.67044385, -1.01780883, ..., -0.76249589,
#          1.39898882,  1.19549442],
#        [ 0.26717004,  0.67044385, -1.01780883, ..., -0.76249589,
#          0.95550207,  1.19549442],
#        [ 0.26717004, -1.49154923,  0.37485853, ..., -0.76249589,
#          0.95550207, -0.56420201]])

# %% [markdown]
# # Train test split

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
Y.value_counts()
# Out:
# 1    158
# 0    129
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 34)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, Y_train)
pred = lr.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(lr, X, Y, cv=None)
cvs.mean()
# Out:
# [[24  2]
#  [ 4 28]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        26
#            1       0.93      0.88      0.90        32
#
#     accuracy                           0.90        58
#    macro avg       0.90      0.90      0.90        58
# weighted avg       0.90      0.90      0.90        58
#
# 0.896551724137931
# 0.8499092558983665

# %%
#RandomForest

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
pred = rf.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(rf, X, Y, cv=None)
cvs.mean()
# Out:
# [[23  3]
#  [ 6 26]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.84        26
#            1       0.90      0.81      0.85        32
#
#     accuracy                           0.84        58
#    macro avg       0.84      0.85      0.84        58
# weighted avg       0.85      0.84      0.85        58
#
# 0.8448275862068966
# 0.8220205686630369

# %%
#DescisonTree

from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,Y_train)
pred = dt.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(dt, X, Y, cv=None)
cvs.mean()
# Out:
# [[23  3]
#  [12 20]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.88      0.75        26
#            1       0.87      0.62      0.73        32
#
#     accuracy                           0.74        58
#    macro avg       0.76      0.75      0.74        58
# weighted avg       0.77      0.74      0.74        58
#
# 0.7413793103448276
# 0.7316394434361767

# %%
#SVC

from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, Y_train)
pred = svc.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(svc, X, Y, cv=None)
cvs.mean()
# Out:
# [[24  2]
#  [ 3 29]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91        26
#            1       0.94      0.91      0.92        32
#
#     accuracy                           0.91        58
#    macro avg       0.91      0.91      0.91        58
# weighted avg       0.91      0.91      0.91        58
#
# 0.9137931034482759
# 0.8396249243799152

# %%
# KNN

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
pred = knn.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))
cvs = cross_val_score(knn, X, Y, cv=None)
cvs.mean()
# Out:
# [[23  3]
#  [ 6 26]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.84        26
#            1       0.90      0.81      0.85        32
#
#     accuracy                           0.84        58
#    macro avg       0.84      0.85      0.84        58
# weighted avg       0.85      0.84      0.85        58
#
# 0.8448275862068966
# 0.8223835450695705

# %% [markdown]
# Suppose these 2 scenarios -
# 1. Model says a person has cancer when in real he hasn't. (False positive)
# 2. Model says a person doesn't have cancer but he has. (False negative)
# Which is more dangerous in this case?
# - The 2nd one right! As wrong detection will make that person live carefree but in real he'll be getting more ill and may also die.
#
# In this case the we will select the model with the lowest False Negative considering the fact that the proportion of actual positives are correctly classified i.e model tells a person has cancer and he actually does.
# The less the no. of false negatives the more the model is perfect in this case.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
C=range(5, 280, 55)
kernel= ['linear', 'poly', 'rbf', 'sigmoid']
degree=[1,2,3,4,5,6]
gamma=['scale', 'auto']
cache_size=[10, 20, 30]
decision_function_shape=['ovo', 'ovr']

random_grid = {'C': C,
               'kernel' : kernel,
               'degree' : degree,
               'gamma' : gamma,
               'cache_size' : cache_size,
               'decision_function_shape' : decision_function_shape}
random_grid
# Out:
# {'C': range(5, 280, 55),
#  'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#  'degree': [1, 2, 3, 4, 5, 6],
#  'gamma': ['scale', 'auto'],
#  'cache_size': [10, 20, 30],
#  'decision_function_shape': ['ovo', 'ovr']}

# %%
svc = SVC()
rscv = RandomizedSearchCV(estimator = svc,
                         param_distributions = random_grid,
                          cv = 10,
                          random_state = 25,
                         verbose = 2,
                         n_jobs = -1)

rscv.fit(X_train, Y_train)
rscv
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomizedSearchCV(cv=10, estimator=SVC(), n_jobs=-1,
#                    param_distributions={'C': range(5, 280, 55),
#                                         'cache_size': [10, 20, 30],
#                                         'decision_function_shape': ['ovo',
#                                                                     'ovr'],
#                                         'degree': [1, 2, 3, 4, 5, 6],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']},
#                    random_state=25, verbose=2)

# %%
rscv.best_params_
# Out:
# {'kernel': 'linear',
#  'gamma': 'auto',
#  'degree': 1,
#  'decision_function_shape': 'ovo',
#  'cache_size': 10,
#  'C': 225}

# %%
rscv.best_estimator_
# Out:
# SVC(C=225, cache_size=10, decision_function_shape='ovo', degree=1, gamma='auto',
#     kernel='linear')

# %%
best_rscv = rscv.best_estimator_
pred = best_rscv.predict(X_test)

print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
print(accuracy_score(Y_test, pred))

cvs = cross_val_score(rscv, X, Y, cv=10)
cvs.mean()
# Out:
# [[23  3]
#  [ 3 29]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        26
#            1       0.91      0.91      0.91        32
#
#     accuracy                           0.90        58
#    macro avg       0.90      0.90      0.90        58
# weighted avg       0.90      0.90      0.90        58
#
# 0.896551724137931
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# ...

# %%
import pickle
filename = 'Heart Disease Detection.pkl'
pickle.dump(knn, open(filename, 'wb'))
