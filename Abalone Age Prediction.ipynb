# %% [markdown]
# # Abalone Age Prediction

# %%
import pandas as pd

# %%
#as jupyter wasn't reading this file, we have to use 'r' as a prefix
df = pd.read_csv(r'F:\abalone_dataset.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# # Data Description :

# %% [markdown]
# Sex: Sex (M: Male, F: Female, I: Infant)
#
# Length: Longest Shell measurement (millimetres - mm)
#
# Diameter: Diameter - perpendicular to length (mm)
#
# Height: Height - with meat in shell (mm)
#
# Whole weight: Weight of whole abalone (grams)
#
# Shucked weight: Weight of meat (grams)
#
# Viscera weight: Gut weight after bleeding (grams)
#
# Shell weight: Shell weight - after being dried (grams)
#
# Rings: Rings - value + 1.5 gives age in years (eg. 4 = 5.5 years)

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # EDA :

# %%
import seaborn as sns
sns.countplot(df['Sex'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.scatterplot(data=df, x='Length', y='Rings')
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.scatterplot(data=df, x='Diameter', y='Rings')
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Rings'>

# %%
sns.scatterplot(data=df, x='Height', y='Rings')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Rings'>

# %%
sns.scatterplot(data=df, x='Whole weight', y='Rings')
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
sns.scatterplot(data=df, x='Shucked weight', y='Rings')
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Rings'>

# %%
sns.scatterplot(data=df, x='Shell weight', y='Rings')
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Rings'>

# %% [markdown]
# # Correlation :

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing dataset

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# The analysis shows that the Ring attribute values ranges from 2 to 29 rings on an abalone specimen. However, the most frequent values of Rings are highly concentrated around the median of the distribution, so that, the 2nd and 3rd quartiles are defined in a range of less than 1 std deviation. We observe that its possible to approximate the distribution of this attribute to a normal curve.

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('variables summary')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# # Outliers Checking :

# %%
df1=df.drop(['Sex'],axis=1)
df1
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# 2           0.2100      9
# 3           0.1550     10
# 4           0.0550      7
# ...            ...    ...
# 4172        0.2490     11
# 4173        0.2605     10
# 4174        0.3080      9
# 4175        0.2960     10
# 4176        0.4950     12
#
# [4177 rows x 8 columns]

# %%
collist=df1.columns.values
ncol=50
nrows=50
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# # Skewness :

# %%
df1.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# # Normal Distribuiton Curve :

# %%
sns.distplot(df1["Length"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df1["Diameter"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df1["Height"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df1["Whole weight"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(df1["Shucked weight"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(df1["Viscera weight"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(df1["Shell weight"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %% [markdown]
# # The normal distritution shows, data is skewed.

# %%
#pip install pandas

# %%
delete=pd.DataFrame([["3.128817","Height","No","Alot"],["0.620927", "Shell weight", "No", "Alot"]],columns=["Correlation with Target", "Column Name", "Normalised", "Outliers"])
delete
# Out:
#   Correlation with Target   Column Name Normalised Outliers
# 0                3.128817        Height         No     Alot
# 1                0.620927  Shell weight         No     Alot

# %%
df2=df1.drop(['Height', 'Shell weight'],axis=1)
df2
# Out:
#       Length  Diameter  Whole weight  Shucked weight  Viscera weight  Rings
# 0      0.455     0.365        0.5140          0.2245          0.1010     15
# 1      0.350     0.265        0.2255          0.0995          0.0485      7
# 2      0.530     0.420        0.6770          0.2565          0.1415      9
# 3      0.440     0.365        0.5160          0.2155          0.1140     10
# 4      0.330     0.255        0.2050          0.0895          0.0395      7
# ...      ...       ...           ...             ...             ...    ...
# 4172   0.565     0.450        0.8870          0.3700          0.2390     11
# 4173   0.590     0.440        0.9660          0.4390          0.2145     10
# 4174   0.600     0.475        1.1760          0.5255          0.2875      9
# 4175   0.625     0.485        1.0945          0.5310          0.2610     10
# 4176   0.710     0.555        1.9485          0.9455          0.3765     12
#
# [4177 rows x 6 columns]

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df1))
z.shape
# Out:
# (4177, 8)

# %%
threshold=3
print(np.where(z<3))
# Out:
# (array([   0,    0,    0, ..., 4176, 4176, 4176], dtype=int64), array([0, 1, 2, ..., 5, 6, 7], dtype=int64))

# %%
df_new=df2[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (4177, 9)
# (4027, 6)

# %% [markdown]
# # Percentage of Data Loss :

# %%
loss_percent=(4177-4027)/4177*4027
print(loss_percent)
# Out:
# 144.6133588700024

# %% [markdown]
# # Model without outliers is df and desired outliers is df_new

# %%
df2
# Out:
#       Length  Diameter  Whole weight  Shucked weight  Viscera weight  Rings
# 0      0.455     0.365        0.5140          0.2245          0.1010     15
# 1      0.350     0.265        0.2255          0.0995          0.0485      7
# 2      0.530     0.420        0.6770          0.2565          0.1415      9
# 3      0.440     0.365        0.5160          0.2155          0.1140     10
# 4      0.330     0.255        0.2050          0.0895          0.0395      7
# ...      ...       ...           ...             ...             ...    ...
# 4172   0.565     0.450        0.8870          0.3700          0.2390     11
# 4173   0.590     0.440        0.9660          0.4390          0.2145     10
# 4174   0.600     0.475        1.1760          0.5255          0.2875      9
# 4175   0.625     0.485        1.0945          0.5310          0.2610     10
# 4176   0.710     0.555        1.9485          0.9455          0.3765     12
#
# [4177 rows x 6 columns]

# %%
x=df2.iloc[:,:-1]
y=df2.iloc[:,:-1]

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.68550213, -0.54986033, -0.57676568, -0.54098937, -0.69328289],
#        [-1.39634403, -1.38733299, -1.35176053, -1.31166208, -1.33295268],
#        [-0.07077438,  0.00853714, -0.19809928, -0.36611642, -0.25513514],
#        ...,
#        [ 0.59336612,  0.64519089,  0.77794363,  0.83813658,  1.01560749],
#        [ 0.85337516,  0.76992788,  0.63387374,  0.85873857,  0.81518436],
#        [ 1.83447784,  1.72628889,  1.93732308,  2.10364827,  1.61134422]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.68550213, -0.54986033, -0.57676568, -0.54098937, -0.69328289],
#        [-1.39634403, -1.38733299, -1.35176053, -1.31166208, -1.33295268],
#        [-0.07077438,  0.00853714, -0.19809928, -0.36611642, -0.25513514],
#        ...,
#        [ 0.59336612,  0.64519089,  0.77794363,  0.83813658,  1.01560749],
#        [ 0.85337516,  0.76992788,  0.63387374,  0.85873857,  0.81518436],
#        [ 1.83447784,  1.72628889,  1.93732308,  2.10364827,  1.61134422]])

# %% [markdown]
# # Splitting the dataframe

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
ln=LinearRegression()
ln.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ln.predict(x_test)
print(y_pred)
# Out:
# [[0.53464141 0.41287636 0.9896394  0.29182743 0.26067581]
#  [0.48621678 0.38734437 0.65941153 0.28111009 0.15467699]
#  [0.61657136 0.47689289 1.26891701 0.53986679 0.36193359]
#  ...
#  [0.63783617 0.49670806 1.17038097 0.52223885 0.30866128]
#  [0.66786596 0.50876794 1.59206633 0.49917709 0.29829844]
#  [0.61797737 0.48317493 1.23047172 0.49719371 0.3072512 ]]

# %%
#Evaluate model
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9738477804834558

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# # Multivariate Analysis :

# %% [markdown]
# In this section we analyzed how the dataset attributes are related and how the independent variables influences the target variable. Our first step in the multivariate analysis was to visualize the correlation matrix in a heatmap:

# %%
#Target attribute
df.Rings.describe()
# Out:
# count    4177.000000
# mean        9.933684
# std         3.224169
# min         1.000000
# 25%         8.000000
# 50%         9.000000
# 75%        11.000000
# max        29.000000
# Name: Rings, dtype: float64

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(), annot = True); # annot = true : to display the correlation value in the graph.

# %% [markdown]
# Analyzing the correlation matrix, we notice that Height and Shell weight are the attributes that most correlates to Rings. Therefore, we concentrated the multivariate analysis on the correlation of these two attributes with Rings:

# %%
plt.figure(figsize=(10, 5))
sns.jointplot(data=df, x='Rings', y='Height', kind='reg');
sns.jointplot(data=df, x='Rings', y='Shell weight', kind='reg');

# %% [markdown]
# # How correlation varies with the number of rings ?

# %% [markdown]
# Based on the previous analysis, we decided to investigate the variation of the correlation regarding the number of rings in more detail. We tested for many values, and found that the region delimited by Rings < 10 has greater correlation between the independent attributes and the target variable.

# %%
i_abalone = df[df['Rings'] < 10]

plt.figure(figsize=(10, 8))
corr = i_abalone.corr()
sns.heatmap(corr, annot=True);

# %% [markdown]
# # Lets see the correlation between size attributes and Rings.

# %%
plt.figure(figsize=(20, 5))

sns.jointplot(data=i_abalone, x='Rings', y='Length', kind='reg')
sns.jointplot(data=i_abalone, x='Rings', y='Diameter', kind='reg')
sns.jointplot(data=i_abalone, x='Rings', y='Height', kind='reg')

# %% [markdown]
# # The violin plots bellow show that the median of Size attributes increases as instances are grouped by Rings:

# %%
plt.figure(figsize=(10,15))
plt.subplot(3,1,1)
sns.violinplot(data=i_abalone, x='Rings', y='Length')
plt.subplot(3,1,2)
sns.violinplot(data=i_abalone, x='Rings', y='Diameter')
plt.subplot(3,1,3)
sns.violinplot(data=i_abalone, x='Rings', y='Height');

# %% [markdown]
# # We observe a similar result where comparing Height and Shell weight to Rings:

# %%
plt.figure(figsize=(20, 5))
sns.jointplot(data=i_abalone, x='Rings', y='Height', kind='reg');
sns.jointplot(data=i_abalone, x='Rings', y='Shell weight', kind='reg');

# %% [markdown]
# # On the other hand, when we consider only samples with more than 10 Rings we observe that correlation decays drastically to near 0 (zero)

# %%
# How correlation shows when Rings more than 10
a_abalone = df[df['Rings'] >= 10]

plt.figure(figsize=(10, 8))
corr = a_abalone.corr()
sns.heatmap(corr, annot=True);

# %%
plt.figure(figsize=(20, 10))

sns.jointplot(data=a_abalone, y='Height', x='Rings', kind='reg');
sns.jointplot(data=a_abalone, y='Shell weight', x='Rings', kind='reg');

# %% [markdown]
# These results suggest that abalones grows in size and weight until a certain age, near 10 years. After this age their size and age remains stable in function of age, depending more on environmental factors.

# %% [markdown]
# # Model Saving :

# %%
import pickle
filename = 'World Happiness Score.pkl'
pickle.dump(ln, open(filename, 'wb'))

# %% [markdown]
# .

# %% [markdown]
# # This one was challenging, is there any source where we can see the actual codes for this ne or better understanding and future purposes?
